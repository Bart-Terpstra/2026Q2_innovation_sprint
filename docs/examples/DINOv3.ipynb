# %% [markdown]
# <a href="https://colab.research.google.com/github/Bart-Terpstra/2026Q2_innovation_sprint/blob/main/docs/examples/DINOv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find similar patches with DINOv3
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/DINOv3.ipynb)
#
# This notebook demonstrates how to find similar patches with [DINOv3](https://github.com/facebookresearch/dinov3).
#
# ## Install packages
#
# To use the new functionality, ensure the required packages are installed.

# %%
# !pip install geoai-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.9/600.9 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.8/666.8 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 54.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 61.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import libraries

# %%
import geoai

# %% [markdown]
# ## Download sample data

# %%
url = (
    "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/naip_rgb_train.tif"
)
raster_path = geoai.download_file(url)

# %% [markdown]
# ## Initialize the DINOv3 processor

# %%
processor = geoai.DINOv3GeoProcessor(
    model_name="dinov3_vitl16",
)
# Out:
# dinov3_vitl16_sat493m.pth:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# Downloading: "https://github.com/facebookresearch/dinov3/zipball/main" to /root/.cache/torch/hub/main.zip

# %% [markdown]
# ## Extract features

# %%
image = "naip_rgb_train.tif"
features, h_patches, w_patches = processor.extract_features(image)

# %% [markdown]
# ## Find similar patches

# %%
m = geoai.LeafMap()
m.add_dinov3_gui(image, processor, features)
m

# %% [markdown]
# ![](https://github.com/user-attachments/assets/5bb0c1d8-cb2a-4e67-ae9d-f31e383bae80)
